# %%
import shutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# !wget https://toil-xena-hub.s3.us-east-1.amazonaws.com/download/tcga_gene_expected_count.gz
# !wget https://tcga-pancan-atlas-hub.s3.us-east-1.amazonaws.com/download/EB%2B%2BAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.xena.gz
# Out:
# --2023-03-09 19:22:37--  https://toil-xena-hub.s3.us-east-1.amazonaws.com/download/tcga_gene_expected_count.gz
# Resolving toil-xena-hub.s3.us-east-1.amazonaws.com (toil-xena-hub.s3.us-east-1.amazonaws.com)... 52.216.138.86, 3.5.16.105, 52.216.17.253, ...
# Connecting to toil-xena-hub.s3.us-east-1.amazonaws.com (toil-xena-hub.s3.us-east-1.amazonaws.com)|52.216.138.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 743185787 (709M) [binary/octet-stream]
# Saving to: ‘tcga_gene_expected_count.gz’
#
# tcga_gene_expected_ 100%[===================>] 708.76M  19.8MB/s    in 32s
#
# 2023-03-09 19:23:10 (21.8 MB/s) - ‘tcga_gene_expected_count.gz’ saved [743185787/743185787]

# %%
# !gzip -d tcga_gene_expected_count.gz

# %%
# !ls /content/drive/MyDrive
# Out:
# Untitled0.ipynb

# %%
shutil.copy('tcga_gene_expected_count', '/content/drive/MyDrive/tcga_gene_expected_count')
# Out:
# '/content/drive/MyDrive/tcga_gene_expected_count'
